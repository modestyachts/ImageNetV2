# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

import os
import sys

import matplotlib.pyplot as plt

repo_root = os.path.join(os.getcwd(), '../code')
sys.path.append(repo_root)

import candidate_data
import image_loader
import imagenet
import utils

# %%
cds = candidate_data.CandidateData()
imgnet = imagenet.ImageNetData()
img_loader = image_loader.ImageLoader(imgnet, cds)
# Out:
# Loaded 169427 unique candidates from 104 search result JSON file(s).
#     /Users/ludwig/research/deep_learning/imagenet_2/data/search_results/...
#         2018-07-31_flickr_search_result_vaishaal_class_1_153.json
#         2018-08-20-16-10-18_becca.json
#         2018-08-25-11-43-09_becca.json
#         2018-08-27-22-53-45_becca.json
#         2018-08-30-02-40-26_becca.json
#         2018-08-30-18-46-35_becca.json
#         2018-08-30-19-31-10_becca.json
#         2018-09-04-17-03-01_becca.json
#         2018-09-04-17-36-03_becca.json
#         2018-09-05-16-16-14_becca.json
#         ...
#     There were 66415 duplicate occurences.
#     Ignored 1721 candidate entries because they are on the blacklist (blacklist size: 2097).
# Reading from local file /Users/ludwig/research/deep_learning/imagenet_2/data/cache/metadata/imagenet_metadata_2018-09-14_01-26-58_UTC.pickle ... done

# %%
tmpimg = img_loader.load_image('n01443537_8401.JPEG', size='scaled_256')

print(type(tmpimg))

plt.figure()
plt.imshow(tmpimg)
plt.show()
# Out:
# Reading from local file /Users/ludwig/research/deep_learning/imagenet_2/data/cache/imagenet-train-individual/n01443537/n01443537_8401.JPEG ... done
# <class 'imageio.core.util.Image'>
# <img src="data:image/png;base64,..." width="640">

# %%
tmpimg = img_loader.load_image('n01443537_8401.JPEG', size='scaled_256', loader='pillow')
print(type(tmpimg))
tmpimg
# Out:
# Reading from local file /Users/ludwig/research/deep_learning/imagenet_2/data/cache/imagenet-train-individual/n01443537/n01443537_8401.JPEG ... done
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x1248A1668>

# %%
img_loader.get_wnid_of_image('n01443537_8401.JPEG')
# Out:
# 'n01443537'

# %%
filenames = ['ILSVRC2012_val_00005870.JPEG', 'n01443537_8401.JPEG', 'n01498041_13465.JPEG', 'n01498041_11953.JPEG', 'f0ca9477a336a4e9ab5a7db0fc7221c0b4a68456']

tmp_res = img_loader.load_image_batch(filenames, size='scaled_256', force_rgb=True)

for fn in filenames:
    plt.figure()
    plt.imshow(tmp_res[fn])
    plt.show()
# Out:
# Reading from local file /Users/ludwig/research/deep_learning/imagenet_2/data/cache/imagenet-train-individual/n01443537/n01443537_8401.JPEG ... done
# Reading from local file /Users/ludwig/research/deep_learning/imagenet_2/data/cache/imagenet-train-individual/n01498041/n01498041_13465.JPEG ... done
# Reading from local file /Users/ludwig/research/deep_learning/imagenet_2/data/cache/imagenet-train-individual/n01498041/n01498041_11953.JPEG ... done
# Reading from local file /Users/ludwig/research/deep_learning/imagenet_2/data/cache/imagenet-validation-individual/n01443537/ILSVRC2012_val_00005870.JPEG ... done
# Reading from local file /Users/ludwig/research/deep_learning/imagenet_2/data/cache/imagenet2candidates_scaled/f0ca9477a336a4e9ab5a7db0fc7221c0b4a68456.jpg ... done
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
wnid = img_loader.get_wnid_of_image('f0ca9477a336a4e9ab5a7db0fc7221c0b4a68456')
print(wnid)
print(imgnet.class_info_by_wnid[wnid].synset)
# Out:
# n01498041
# ['stingray']

# %%
filenames = ['ILSVRC2012_val_00005870.JPEG', 'n01443537_8401.JPEG', 'n01498041_13465.JPEG', 'n01498041_11953.JPEG', 'f0ca9477a336a4e9ab5a7db0fc7221c0b4a68456']

tmpres = img_loader.load_features_batch(filenames)

res_d = len(list(tmpres.values())[0])
for v in tmpres.values():
    assert len(v) == res_d
print('Number of entries {}, all with dimension {}.'.format(len(tmpres), res_d))
# Out:
# Reading from local file /Users/ludwig/research/deep_learning/imagenet_2/data/cache/imagenet-train-featurized/n01443537-fc7.pkl ... done
# Reading from local file /Users/ludwig/research/deep_learning/imagenet_2/data/cache/imagenet-train-featurized/n01498041-fc7.pkl ... done
# Reading from local file /Users/ludwig/research/deep_learning/imagenet_2/data/cache/imagenet-validation-featurized/val-n01443537-fc7.pkl ... done
# Reading from local file /Users/ludwig/research/deep_learning/imagenet_2/data/cache/imagenet2candidates_featurized/f0ca9477a336a4e9ab5a7db0fc7221c0b4a68456.npy ... done
# Number of entries 5, all with dimension 4096.
